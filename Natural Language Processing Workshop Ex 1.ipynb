# %% [markdown]
# # Natural Language Processing Workshop Ex 1
#
# This is a simple exercise for you to execute some NLP Text Processing methods.
#
# The methods covered:
# NLTK
# - Tokenization
# - Sentenance
# - Lemmentation
# - Tagging
#
# - Basic Text Processing Approach
# - removing Stopwords
#
# http://billchambers.me/tutorials/2015/01/14/python-nlp-cheatsheet-nltk-scikit-learn.html

# %%
import nltk

# %% [markdown]
# Download the Corpora
# - stopwords
# - brown
#
# Toggle the Below Cell [y/m] to download the NLTK Packages

# %% [markdown]
# nltk.download()

# %% [markdown]
# ## Part 1: String manipulation using Regular Expression
#
# Why use Regular Expression?
# - split
# - find
# - replace
#
# Resources :
# - https://docs.python.org/3/howto/regex.html
# - https://www.datacamp.com/community/tutorials/python-regular-expression-tutorial
# - https://regexr.com/

# %%
import re

# %%
my_string = "Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences?  Or perhaps, all 19 words?"

# %% [markdown]
# #### How do you split a string into sentences?
# - notice where is the punctuation

# %%
sentence_ending = r"[.?!]"

# Split my_string on sentence endings and print the result
print(re.split(sentence_ending, my_string))
# Out:
# ["Let's write RegEx", "  Won't that be fun", '  I sure think so', '  Can you find 4 sentences', '  Or perhaps, all 19 words', '']

# %%
# Find all capitalized words in my_string and print the result
capitalized_words = r"[A-Z]\w+"
print(re.findall(capitalized_words, my_string))
# Out:
# ['Let', 'RegEx', 'Won', 'Can', 'Or']

# %%
# Split my_string on spaces and print the result
spaces = r"[\s+]"
print(re.split(spaces, my_string))

token = r"\w+"
print(re.findall(token, my_string))
# Out:
# ["Let's", 'write', 'RegEx!', '', "Won't", 'that', 'be', 'fun?', '', 'I', 'sure', 'think', 'so.', '', 'Can', 'you', 'find', '', 'digit', '', 'sentences?', '', 'Or', 'perhaps,', 'all', '', 'digit', '', 'digit', '', 'words?']
# ['Let', 's', 'write', 'RegEx', 'Won', 't', 'that', 'be', 'fun', 'I', 'sure', 'think', 'so', 'Can', 'you', 'find', 'digit', 'sentences', 'Or', 'perhaps', 'all', 'digit', 'digit', 'words']

# %%
# Find all digits in my_string and print the result
digit = r"[\d]"
print(re.findall(digit, my_string))
digits = r"\d+"
print(re.findall(digits, my_string))
# Out:
# ['4', '1', '9']
# ['4', '19']

# %%
my_string = re.sub(digit, " digit ", my_string)
print(my_string)
# Out:
# Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find  digit  sentences?  Or perhaps, all  digit  digit  words?

# %% [markdown]
# ## Word Tokenizing with NLTK

# %%
############### LOADING TEXT ###############
shakespeare = ""

with open("shakespeare.txt",'r') as file:
    file.readline()
    for line in file:
        data = str(line).strip()
        shakespeare = shakespeare + data + ' '
        
shakespeare = shakespeare.lower()

# %% [markdown]
# ## 1. Tokenization
#
# – whitespace, newline, blankline, word, treebank, sexpr, regexp,
# Punkt sentence segmenter

# %%
############### Word Tokenize vs Sent Tokenize ###############

# Import necessary modules
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# How many words in this text file?
ss_wordtokens = word_tokenize(shakespeare)
# print(ss_wordtokens)
# print(len(ss_wordtokens))

# How many senetences in this text file?
ss_senttokens = sent_tokenize(shakespeare)
# print(ss_senttokens)
# print(len(ss_senttokens))

# How many Unique Words are there?
unique_tokens = set(word_tokenize(shakespeare))
print(len(unique_tokens))
# Out:
# 333

# %%
############### Regexp Tokenizer ###############
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')

ss_regword_tokens = tokenizer.tokenize(shakespeare)

# print(ss_regword_tokens)
# print(len(ss_regword_tokens))

# What is the difference with WordTokenizer and RegexpTokenizer?
# Out:
# ['from', 'fairest', 'creatures', 'we', 'desire', 'increase', 'that', 'thereby', 'beauty', 's', 'rose', 'might', 'never', 'die', 'but', 'as', 'the', 'riper', 'should', 'by', 'time', 'decease', 'his', 'tender', 'heir', 'might', 'bear', 'his', 'memory', 'but', 'thou', 'contracted', 'to', 'thine', 'own', 'bright', 'eyes', 'feed', 'st', 'thy', 'light', 's', 'flame', 'with', 'self', 'substantial', 'fuel', 'making', 'a', 'famine', 'where', 'abundance', 'lies', 'thy', 'self', 'thy', 'foe', 'to', 'thy', 'sweet', 'self', 'too', 'cruel', 'thou', 'that', 'art', 'now', 'the', 'world', 's', 'fresh', 'ornament', 'and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring', 'within', 'thine', 'own', 'bud', 'buriest', 'thy', 'content', 'and', 'tender', 'churl', 'mak', 'st', 'waste', 'in', 'niggarding', 'pity', 'the', 'world', 'or', 'else', 'this', 'glutton', 'be', 'to', 'eat', 'the', 'world', 's', 'due', 'by', 'the', 'grave', 'and', 'thee', 'when', 'forty', 'winters', 'shall', 'besiege', 'thy', 'brow', 'and', 'dig', 'deep', 'trenches', 'in', 'thy', 'beauty', 's', 'field', 'thy', 'youth', 's', 'proud', 'livery', 'so', 'gazed', 'on', 'now', 'will', 'be', 'a', 'tattered', 'weed', 'of', 'small', 'worth', 'held', 'then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies', 'where', 'all', 'the', 'treasure', 'of', 'thy', 'lusty', 'days', 'to', 'say', 'within', 'thine', 'own', 'deep', 'sunken', 'eyes', 'were', 'an', 'all', 'eating', 'shame', 'and', 'thriftless', 'praise', 'how', 'much', 'more', 'praise', 'deserved', 'thy', 'beauty', 's', 'use', 'if', 'thou', 'couldst', 'answer', 'this', 'fair', 'child', 'of', 'mine', 'shall', 'sum', 'my', 'count', 'and', 'make', 'my', 'old', 'excuse', 'proving', 'his', 'beauty', 'by', 'succession', 'thine', 'this', 'were', 'to', 'be', 'new', 'made', 'when', 'thou', 'art', 'old', 'and', 'see', 'thy', 'blood', 'warm', 'when', 'thou', 'feel', 'st', 'it', 'cold', 'look', 'in', 'thy', 'glass', 'and', 'tell', 'the', 'face', 'thou', 'viewest', 'now', 'is', 'the', 'time', 'that', 'face', 'should', 'form', 'another', 'whose', 'fresh', 'repair', 'if', 'now', 'thou', 'not', 'renewest', 'thou', 'dost', 'beguile', 'the', 'world', 'unbless', 'some', 'mother', 'for', 'where', 'is', 'she', 'so', 'fair', 'whose', 'uneared', 'womb', 'disdains', 'the', 'tillage', 'of', 'thy', 'husbandry', 'or', 'who', 'is', 'he', 'so', 'fond', 'will', 'be', 'the', 'tomb', 'of', 'his', 'self', 'love', 'to', 'stop', 'posterity', 'thou', 'art', 'thy', 'mother', 's', 'glass', 'and', 'she', 'in', 'thee', 'calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime', 'so', 'thou', 'through', 'windows', 'of', 'thine', 'age', 'shalt', 'see', 'despite', 'of', 'wrinkles', 'this', 'thy', 'golden', 'time', 'but', 'if', 'thou', 'live', 'remembered', 'not', 'to', 'be', 'die', 'single', 'and', 'thine', 'image', 'dies', 'with', 'thee', 'unthrifty', 'loveliness', 'why', 'dost', 'thou', 'spend', 'upon', 'thy', 'self', 'thy', 'beauty', 's', 'legacy', 'nature', 's', 'bequest', 'gives', 'nothing', 'but', 'doth', 'lend', 'and', 'being', 'frank', 'she', 'lends', 'to', 'those', 'are', 'free', 'then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse', 'the', 'bounteous', 'largess', 'given', 'thee', 'to', 'give', 'profitless', 'usurer', 'why', 'dost', 'thou', 'use', 'so', 'great', 'a', 'sum', 'of', 'sums', 'yet', 'canst', 'not', 'live', 'for', 'having', 'traffic', 'with', 'thy', 'self', 'alone', 'thou', 'of', 'thy', 'self', 'thy', 'sweet', 'self', 'dost', 'deceive', 'then', 'how', 'when', 'nature', 'calls', 'thee', 'to', 'be', 'gone', 'what', 'acceptable', 'audit', 'canst', 'thou', 'leave', 'thy', 'unused', 'beauty', 'must', 'be', 'tombed', 'with', 'thee', 'which', 'used', 'lives', 'th', 'executor', 'to', 'be', 'those', 'hours', 'that', 'with', 'gentle', 'work', 'did', 'frame', 'the', 'lovely', 'gaze', 'where', 'every', 'eye', 'doth', 'dwell', 'will', 'play', 'the', 'tyrants', 'to', 'the', 'very', 'same', 'and', 'that', 'unfair', 'which', 'fairly', 'doth', 'excel', 'for ...
# 681

# %% [markdown]
# ## 2. Stopwords + Punctuation

# %%
############### STOPWORDS ###############
# What are stopwords? 

# Import necessary modules
from nltk.corpus import stopwords

stop_words = stopwords.words('english')

print(type(stop_words))
print(stop_words)

# Are there anymore stopwords not included?
# Are you able to add or remove your own stopwords?

stop_words.append('thy')
print(stop_words[-1])

stop_words.remove('i')
print(stop_words)
# Out:
# <class 'list'>
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# thy
# ['me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'thy']

# %%
# Now you have to remove the stopwords from the content
# After removing, how many words are there left?
clean_text = []

print(len(ss_regword_tokens))

for w in ss_regword_tokens:
    if w not in stop_words:
        clean_text.append(w)
        
print(len(clean_text))
# Out:
# 681
# 394

# %% [markdown]
# ## 3. Stemming vs Lemmatization
#
# – Porter, Lancaster, regexp, Snowball

# %%
############### Stemming ###############
# What is stemming?

from nltk.stem import PorterStemmer
from nltk.stem.lancaster import LancasterStemmer

porter_stemmer = PorterStemmer()

#how does stemmer words?
test_words= ["cement", "owed", "maximum", "community"]
# test_words= ["understand", "understands", "understanding"]

for w in test_words: 
    print(porter_stemmer.stem(w))

# Other Forms for Stemmer
lancaster_stemmer = LancasterStemmer()
for w in test_words: 
    print(lancaster_stemmer.stem(w))
# Out:
# cement
# owe
# maximum
# commun
# cem
# ow
# maxim
# commun

# %%
############### LEMMATIZATION ###############
# What is the difference with Stemming and Lemmatization

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

test_words= ["churches", "abaci","community", "are", "is"]

for w in test_words: 
    print(lemmatizer.lemmatize(w))
    
# WordNet superficially resembles a thesaurus, but...

print(lemmatizer.lemmatize('is', pos='v'))
print(lemmatizer.lemmatize('are', pos='v'))
print(lemmatizer.lemmatize('better', pos='a'))
print(lemmatizer.lemmatize('run'))
# Out:
# church
# abacus
# community
# are
# is
# be
# be
# good
# run

# %% [markdown]
# ## 4. Frequency Distribution

# %%
############### Visualizing with NLTK ###############
from nltk import FreqDist

fd = FreqDist(clean_text)
fd.plot()
fd.plot(50, cumulative=True)
fd.most_common(12)
# Out:
# [('thou', 21),
#  ('self', 12),
#  ('beauty', 11),
#  ('thee', 10),
#  ('thine', 8),
#  ('art', 5),
#  ('dost', 5),
#  ('ten', 5),
#  ('time', 4),
#  ('sweet', 4),
#  ('world', 4),
#  ('st', 3)]

# %%
############### Visualizing with WORDCLOUD ###############
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS

def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(words)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    #plt.savefig('WordCloud.png', dpi=300)
    
wordcloud_draw(clean_text,'white')

# %% [markdown]
# ## 4. POS Tagging
# - Brown Tagger
# - Penn Tree Tagger

# %%
############### POS Tagging ###############

# 1. NLTK POS Tagger
from nltk import pos_tag
output = pos_tag(clean_text)

# print(output)

#nltk.help.upenn_tagset("PRP$")

# %%
from nltk.corpus import brown
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.most_common()
# Out:
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %% [markdown]
# ## 5. Collocation, Unigram, Bigram, Trigrams (N-grams)
